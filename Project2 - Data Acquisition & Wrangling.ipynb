# %% [markdown]
# # Task -1

# %%
#import functions 
import pandas as pd
import numpy as np

# %%
#import files 
ds1=pd.read_csv('dataset_1.csv')
ds2=pd.read_csv('dataset_2.csv')

# %%
#rename columns
ds1 = ds1.rename(columns={'instant': 'instant', 'dteday': 'date', 'season': 'season', 'yr':'year','mnth':'month','hr':'hour','holiday':'holiday','weekday':'weekday','weathersit':'weather','temp':'temprature'})

ds1
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature
# 0          1        0.24
# 1          1        0.22
# 2          1        0.22
# ...

# %%
#rename columns
ds2 = ds2.rename(columns={'instant': 'instant', 'atemp': 'temp', 'hum': 'humidity', 'windspeed':'windspeed','casual':'casual','registered':'registered','cnt':'count','unanamed':'Sr'})

ds2
# Out:
#      Unnamed: 0  instant    temp  humidity  windspeed  casual  registered  \
# 0             0        1  0.2879      0.81     0.0000       3          13
# 1             1        2  0.2727      0.80     0.0000       8          32
# 2             2        3  0.2727      0.80     0.0000       5          27
# 3             3        4  0.2879      0.75     0.0000       3          10
# 4             4        5  0.2879      0.75     0.0000       0           1
# ..          ...      ...     ...       ...        ...     ...         ...
# 605         605      606  0.2121      0.93     0.1045       0          30
# 606         606      607  0.2121      0.93     0.1045       1          28
# 607         607      608  0.2121      0.93     0.1045       0          31
# 608         608      609  0.2727      0.80     0.0000       2          36
# 609         609      610  0.2576      0.86     0.0000       1          40
#
#      count
# 0       16
# 1       40
# 2       32
# 3       13
# 4        1
# ...

# %%
#remove unwanted columns
columns_without_heading = [col for col in ds2.columns if pd.isna(col)]
ds2 = ds2.drop(columns_without_heading, axis=0)
ds2.to_csv('new_dataset_2.csv', index=False)
ds3=pd.read_csv('new_dataset_2.csv')

# %%
ds3
# Out:
#      Unnamed: 0  instant    temp  humidity  windspeed  casual  registered  \
# 0             0        1  0.2879      0.81     0.0000       3          13
# 1             1        2  0.2727      0.80     0.0000       8          32
# 2             2        3  0.2727      0.80     0.0000       5          27
# 3             3        4  0.2879      0.75     0.0000       3          10
# 4             4        5  0.2879      0.75     0.0000       0           1
# ..          ...      ...     ...       ...        ...     ...         ...
# 605         605      606  0.2121      0.93     0.1045       0          30
# 606         606      607  0.2121      0.93     0.1045       1          28
# 607         607      608  0.2121      0.93     0.1045       0          31
# 608         608      609  0.2727      0.80     0.0000       2          36
# 609         609      610  0.2576      0.86     0.0000       1          40
#
#      count
# 0       16
# 1       40
# 2       32
# 3       13
# 4        1
# ...

# %%
# 1 Merge Method 

merged_data = pd.merge(ds1, ds2, on='instant', how='outer')

merged_data
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
#Concatenate datasets
ds1["holiday"] = ds1["holiday"].astype("boolean")
concatenate = pd.concat([ds1, ds2])

concatenate
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011     1.0   0.0    1.0   0.0    False      6.0
# 1          2  01-01-2011     1.0   0.0    1.0   1.0    False      6.0
# 2          3  01-01-2011     1.0   0.0    1.0   2.0    False      6.0
# 3          4  01-01-2011     1.0   0.0    1.0   3.0    False      6.0
# 4          5  01-01-2011     1.0   0.0    1.0   4.0    False      6.0
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606         NaN     NaN   NaN    NaN   NaN     <NA>      NaN
# 606      607         NaN     NaN   NaN    NaN   NaN     <NA>      NaN
# 607      608         NaN     NaN   NaN    NaN   NaN     <NA>      NaN
# 608      609         NaN     NaN   NaN    NaN   NaN     <NA>      NaN
# 609      610         NaN     NaN   NaN    NaN   NaN     <NA>      NaN
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
ds3=merged_data

ds3
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
#identify unique values
unique_values = ds3.nunique()
# Print the results
print(unique_values)
# Out:
# instant       610
# date           28
# season          1
# year            1
# month           1
# hour           24
# holiday         2
# weekday         7
# weather         4
# temprature     23
# Unnamed: 0    610
# temp           29
# humidity       61
# windspeed      20
# casual         32
# registered    150
# count         165
# dtype: int64

# %%
#Check the dimension of the dataset
print('dataset_1 -',ds1.shape)
print('dataset_2 -',ds2.shape)
print('Merged dataset 1 & 2 -',ds3.shape)
# Out:
# dataset_1 - (610, 10)
# dataset_2 - (610, 8)
# Merged dataset 1 & 2 - (610, 17)

# %%
#Check the datatype of the dataset
print('dataset_1 -',ds1.dtypes)
print("---------------------------")
print('dataset_2 -',ds2.dtypes)
print("----------------------------")
print('Merged dataset 1 & 2 -',ds3.dtypes)
# Out:
# dataset_1 - instant         int64
# date           object
# season          int64
# year            int64
# month           int64
# hour            int64
# holiday       boolean
# weekday         int64
# weather         int64
# temprature    float64
# dtype: object
# ---------------------------
# dataset_2 - Unnamed: 0      int64
# instant         int64
# temp          float64
# humidity      float64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object
# ----------------------------
# Merged dataset 1 & 2 - instant         int64
# date           object
# season          int64
# year            int64
# month           int64
# hour            int64
# holiday          bool
# weekday         int64
# weather         int64
# temprature    float64
# Unnamed: 0      int64
# temp          float64
# humidity      float64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
ds3['windspeed'] = ds3['windspeed'].astype('int')
print(ds3.dtypes)
# Out:
# instant         int64
# date           object
# season          int64
# year            int64
# month           int64
# hour            int64
# holiday          bool
# weekday         int64
# weather         int64
# temprature    float64
# Unnamed: 0      int64
# temp          float64
# humidity      float64
# windspeed       int32
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
ds3
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
#Check datatype summary
#print('Merged dataset 1 & 2 -',ds3.info)
ds3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   date        610 non-null    object
#  2   season      610 non-null    int64
#  3   year        610 non-null    int64
#  4   month       610 non-null    int64
#  5   hour        610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weather     610 non-null    int64
#  9   temprature  610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  temp        599 non-null    float64
#  12  humidity    610 non-null    float64
#  13  windspeed   610 non-null    int32
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  count       610 non-null    int64
# dtypes: bool(1), float64(3), int32(1), int64(11), object(1)
# memory usage: 79.2+ KB

# %%
#Validate Data
missing_values = ds3.isnull().sum()
# Print the number of missing values
print(missing_values)
# Out:
# instant        0
# date           0
# season         0
# year           0
# month          0
# hour           0
# holiday        0
# weekday        0
# weather        0
# temprature     0
# Unnamed: 0     0
# temp          11
# humidity       0
# windspeed      0
# casual         0
# registered     0
# count          0
# dtype: int64

# %%
# Treat missing values
ds3.fillna(ds3.mean(), inplace=True)

ds3.head(25)
# Out:
# C:\Users\girish.patil\AppData\Local\Temp\ipykernel_7792\2322065534.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds3.fillna(ds3.mean(), inplace=True)
#     instant        date  season  year  month  hour  holiday  weekday  weather  \
# 0         1  01-01-2011       1     0      1     0    False        6        1
# 1         2  01-01-2011       1     0      1     1    False        6        1
# 2         3  01-01-2011       1     0      1     2    False        6        1
# 3         4  01-01-2011       1     0      1     3    False        6        1
# 4         5  01-01-2011       1     0      1     4    False        6        1
# 5         6  01-01-2011       1     0      1     5    False        6        2
# ...

# %%
#Drop column which is not required
drop=ds3.drop(['Unnamed: 0'],axis=1)

# %%
drop
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature    temp  humidity  windspeed  casual  registered  \
# ...

# %%
ds3
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
#Central Tendency 
import pandas as pd
central_tendency= ds3['casual']

#Mean 
mean= central_tendency.mean()
print('Mean -',mean)

#median 
median= central_tendency.median()
print('Median -',median)

#mode
mode= central_tendency.mode()
print('Mode -',mode)
# Out:
# Mean - 4.501639344262295
# Median - 2.0
# Mode - 0    0
# Name: casual, dtype: int64

# %%
ds3
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %%
#import files 
ds1=pd.read_csv('dataset_1.csv')
ds2=pd.read_csv('dataset_2.csv')

# Assume 'temperature' is the common column name in both datasets
combined_dataset = pd.concat([ds1, ds2], ignore_index=True)

#Compute the z-score.
z_score = stats.zscore(combined_dataset['registered'])

#Append the z-score to the original datasets.
ds1['z_score'] = z_score[:len(ds1)]
ds2['z_score'] = z_score[len(ds1):]

#Identify Outlier
# Set the threshold for identifying outliers
threshold = 0.2727

# Define a function to identify outliers
def identify_outliers(dataset):
    outliers = dataset[(dataset['z_score'] < -threshold) | (dataset['z_score'] > threshold)]
    return outliers

# Identify outliers in both datasets
outliers_dataset1 = identify_outliers(ds1)
outliers_dataset2 = identify_outliers(ds2)

# %%
outliers_dataset1
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, weathersit, temp, z_score]
# Index: []

# %%
outliers_dataset2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, instant, atemp, hum, windspeed, casual, registered, cnt, z_score]
# Index: []

# %%
#Skewness 
import scipy.stats as stats

ds3['skewness'] = stats.skew(ds3['temprature'])
print(ds3[['temprature', 'skewness']])
# Out:
#      temprature  skewness
# 0          0.24   0.66345
# 1          0.22   0.66345
# 2          0.22   0.66345
# 3          0.24   0.66345
# 4          0.24   0.66345
# ..          ...       ...
# 605        0.18   0.66345
# 606        0.18   0.66345
# 607        0.18   0.66345
# 608        0.22   0.66345
# 609        0.20   0.66345
#
# [610 rows x 2 columns]

# %%
#Histogram with Positive skewness
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

plt.figure(figsize=(10, 6))
sns.histplot(new_data['casual']).set_title('Histogram for Casual')
plt.show()

# %%
#Heatmap
import seaborn as sns


drop=ds3.drop(['Unnamed: 0'],axis=1)
drop=ds3.drop(['season'],axis=1)
drop=ds3.drop(['year'],axis=1)
drop=ds3.drop(['month'],axis=1)
ds3
# Create a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(ds3.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\girish.patil\AppData\Local\Temp\ipykernel_7792\243083279.py:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds3.corr(), annot=True, cmap='coolwarm')

# %%
ds3
# Out:
#      instant        date  season  year  month  hour  holiday  weekday  \
# 0          1  01-01-2011       1     0      1     0    False        6
# 1          2  01-01-2011       1     0      1     1    False        6
# 2          3  01-01-2011       1     0      1     2    False        6
# 3          4  01-01-2011       1     0      1     3    False        6
# 4          5  01-01-2011       1     0      1     4    False        6
# ..       ...         ...     ...   ...    ...   ...      ...      ...
# 605      606  28-01-2011       1     0      1    11    False        5
# 606      607  28-01-2011       1     0      1    12    False        5
# 607      608  28-01-2011       1     0      1    13    False        5
# 608      609  28-01-2011       1     0      1    14    False        5
# 609      610  28-01-2011       1     0      1    15    False        5
#
#      weather  temprature  Unnamed: 0    temp  humidity  windspeed  casual  \
# ...

# %% [markdown]
# # Task-2

# %%
#import files 
dataset3=pd.read_csv('dataset_3.csv')
dataset3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
New_dataset3 = dataset3.rename(columns={'instant': 'instant', 'dteday': 'date', 'season': 'season', 'yr':'year','mnth':'month','hr':'hour','holiday':'holiday','weekday':'weekday','weathersit':'weather','atemp':'temprature','hum':'humidity','cnt':'count'})

New_dataset3.head()
# Out:
#    instant        date  season  year  month  hour  holiday  weekday  weather  \
# 0      620  29-01-2011       1     0      1     1    False        6        1
# 1      621  29-01-2011       1     0      1     2    False        6        1
# 2      622  29-01-2011       1     0      1     3    False        6        1
# 3      623  29-01-2011       1     0      1     4    False        6        1
# 4      624  29-01-2011       1     0      1     6    False        6        1
#
#    temp  temprature  humidity  windspeed  casual  registered  count
# 0  0.22      0.2273      0.64     0.1940       0          20     20
# 1  0.22      0.2273      0.64     0.1642       0          15     15
# 2  0.20      0.2121      0.64     0.1343       3           5      8
# 3  0.16      0.1818      0.69     0.1045       1           2      3
# 4  0.16      0.1818      0.64     0.1343       0           2      2

# %%
#Concatanate ds1+ds2 and ds3

ds1["holiday"] = ds1["holiday"].astype("boolean")
concat_dataset= pd.concat([ds1, ds2,New_dataset3])

concat_dataset
# Out:
#      instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0          1  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1          2  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2          3  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3          4  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4          5  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
# ..       ...         ...     ...  ...   ...  ...     ...      ...         ...
# 385      615         NaN     1.0  NaN   NaN  NaN   False      5.0         NaN
# 386      616         NaN     1.0  NaN   NaN  NaN   False      5.0         NaN
# 387      617         NaN     1.0  NaN   NaN  NaN   False      5.0         NaN
# 388      618         NaN     1.0  NaN   NaN  NaN   False      5.0         NaN
# 389      619         NaN     1.0  NaN   NaN  NaN   False      6.0         NaN
#
# ...

# %%
# Treat missing values
concat_dataset.fillna(concat_dataset.mean(), inplace=True)

concat_dataset
# Out:
# C:\Users\girish.patil\AppData\Local\Temp\ipykernel_7792\2647399557.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   concat_dataset.fillna(concat_dataset.mean(), inplace=True)
#      instant      dteday  season   yr  mnth         hr holiday  weekday  \
# 0          1  01-01-2011     1.0  0.0   1.0   0.000000   False      6.0
# 1          2  01-01-2011     1.0  0.0   1.0   1.000000   False      6.0
# 2          3  01-01-2011     1.0  0.0   1.0   2.000000   False      6.0
# 3          4  01-01-2011     1.0  0.0   1.0   3.000000   False      6.0
# 4          5  01-01-2011     1.0  0.0   1.0   4.000000   False      6.0
# ..       ...         ...     ...  ...   ...        ...     ...      ...
# ...

# %%
#Drop column which is not required
new_dataset=concat_dataset.drop(['Unnamed: 0','temp','weathersit','yr','hr','mnth','cnt',],axis=1)

new_dataset
# Out:
#      instant      dteday  season holiday  weekday  z_score     atemp  \
# 0          1  01-01-2011     1.0   False      6.0      NaN  0.199935
# 1          2  01-01-2011     1.0   False      6.0      NaN  0.199935
# 2          3  01-01-2011     1.0   False      6.0      NaN  0.199935
# 3          4  01-01-2011     1.0   False      6.0      NaN  0.199935
# 4          5  01-01-2011     1.0   False      6.0      NaN  0.199935
# ..       ...         ...     ...     ...      ...      ...       ...
# 385      615         NaN     1.0   False      5.0      NaN  0.199935
# 386      616         NaN     1.0   False      5.0      NaN  0.199935
# 387      617         NaN     1.0   False      5.0      NaN  0.199935
# 388      618         NaN     1.0   False      5.0      NaN  0.199935
# 389      619         NaN     1.0   False      6.0      NaN  0.199935
#
#           hum  windspeed  casual  registered        date  year  month  \
# ...

# %%
#identify unique values
unique_values = new_dataset.nunique()
# Print the results
print(unique_values)
# Out:
# instant       1000
# dteday          28
# season           1
# holiday          3
# weekday          8
# z_score          0
# atemp           30
# hum             62
# windspeed       21
# casual          43
# registered     187
# date            18
# year             1
# month            3
# hour            25
# weather          4
# temprature      23
# humidity        59
# count          145
# dtype: int64

# %%
#Central Tendency 
import pandas as pd
central_tendency= new_datset['temprature']

#Mean 
mean= central_tendency.mean()
print('Mean -',mean)

#median 
median= central_tendency.median()
print('Median -',median)

#mode
mode= central_tendency.mode()
print('Mode -',mode)
# Out:
# Mean - 0.23042384615384617
# Median - 0.23042384615384617
# Mode - 0    0.230424
# Name: temprature, dtype: float64

# %%
new_dataset
# Out:
#      instant      dteday  season holiday  weekday  z_score     atemp  \
# 0          1  2011-01-01     1.0   False      6.0      NaN  0.199935
# 1          2  2011-01-01     1.0   False      6.0      NaN  0.199935
# 2          3  2011-01-01     1.0   False      6.0      NaN  0.199935
# 3          4  2011-01-01     1.0   False      6.0      NaN  0.199935
# 4          5  2011-01-01     1.0   False      6.0      NaN  0.199935
# ..       ...         ...     ...     ...      ...      ...       ...
# 385      615  2011-01-01     1.0   False      5.0      NaN  0.199935
# 386      616  2011-01-01     1.0   False      5.0      NaN  0.199935
# 387      617  2011-01-01     1.0   False      5.0      NaN  0.199935
# 388      618  2011-01-01     1.0   False      5.0      NaN  0.199935
# 389      619  2011-01-01     1.0   False      6.0      NaN  0.199935
#
#           hum  windspeed  casual  registered        date  year  month  \
# ...

# %%
# Drop rows with NaN values
new_dataset['instant'].fillna(value=new_dataset['instant'].mean(), inplace=True)
new_dataset['season'].fillna(value=new_dataset['season'].mean(), inplace=True)
new_dataset['weekday'].fillna(value=new_dataset['weekday'].mean(), inplace=True)
new_dataset['atemp'].fillna(value=new_dataset['atemp'].mean(), inplace=True)
new_dataset['hum'].fillna(value=new_dataset['hum'].mean(), inplace=True)
new_dataset['windspeed'].fillna(value=new_dataset['windspeed'].mean(), inplace=True)
new_dataset['casual'].fillna(value=new_dataset['casual'].mean(), inplace=True)
new_dataset['registered'].fillna(value=new_dataset['registered'].mean(), inplace=True)

new_dataset['year'].fillna(value=new_dataset['year'].mean(), inplace=True)
new_dataset['month'].fillna(value=new_dataset['month'].mean(), inplace=True)
new_dataset['hour'].fillna(value=new_dataset['hour'].mean(), inplace=True)
new_dataset['weather'].fillna(value=new_dataset['weather'].mean(), inplace=True)
new_dataset['temprature'].fillna(value=new_dataset['temprature'].mean(), inplace=True)
new_dataset['humidity'].fillna(value=new_dataset['humidity'].mean(), inplace=True)
new_dataset['count'].fillna(value=new_dataset['count'].mean(), inplace=True)

new_dataset
# Out:
#      instant               dteday  season holiday  weekday  z_score     atemp  \
# 0          1           01-01-2011     1.0   False      6.0      NaN  0.199935
# 1          2           01-01-2011     1.0   False      6.0      NaN  0.199935
# 2          3           01-01-2011     1.0   False      6.0      NaN  0.199935
# 3          4           01-01-2011     1.0   False      6.0      NaN  0.199935
# 4          5           01-01-2011     1.0   False      6.0      NaN  0.199935
# ..       ...                  ...     ...     ...      ...      ...       ...
# 385      615  2011-01-01 00:00:00     1.0   False      5.0      NaN  0.199935
# 386      616  2011-01-01 00:00:00     1.0   False      5.0      NaN  0.199935
# 387      617  2011-01-01 00:00:00     1.0   False      5.0      NaN  0.199935
# 388      618  2011-01-01 00:00:00     1.0   False      5.0      NaN  0.199935
# 389      619  2011-01-01 00:00:00     1.0   False      6.0      NaN  0.199935
#
# ...

# %%
new_dataset=new_dataset.drop(['z_score'],axis=1)

# %%
new_dataset
# Out:
#      instant      dteday  season holiday  weekday     atemp       hum  \
# 0          1  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 1          2  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 2          3  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 3          4  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 4          5  2011-01-01     1.0   False      6.0  0.199935  0.562475
# ..       ...         ...     ...     ...      ...       ...       ...
# 385      615  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 386      616  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 387      617  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 388      618  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 389      619  2011-01-01     1.0   False      6.0  0.199935  0.562475
#
#      windspeed  casual  registered        date  year  month       hour  \
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'datetime_column' is your datetime column
new_dataset['dteday'] = pd.to_datetime(new_dataset['dteday'])
new_dataset['date'] = pd.to_datetime(new_dataset['date'])

# Convert the datetime column to only date
new_dataset['dteday'] = new_dataset['dteday'].dt.date
new_dataset['date'] = new_dataset['date'].dt.date

# Now the 'date_only' column contains only the date part of the 'datetime_column'
print(new_dataset[['dteday']])
print(new_dataset[['date']])
# Out:
#          dteday
# 0    2011-01-01
# 1    2011-01-01
# 2    2011-01-01
# 3    2011-01-01
# 4    2011-01-01
# ..          ...
# 385  2011-01-01
# 386  2011-01-01
# 387  2011-01-01
# 388  2011-01-01
# 389  2011-01-01
#
# [1610 rows x 1 columns]
#            date
# 0    2011-01-01
# 1    2011-01-01
# 2    2011-01-01
# 3    2011-01-01
# 4    2011-01-01
# ..          ...
# 385  2011-01-28
# 386  2011-01-28
# 387  2011-01-28
# 388  2011-01-28
# 389  2011-01-29
#
# [1610 rows x 1 columns]

# %%
new_dataset
# Out:
#      instant      dteday  season holiday  weekday     atemp       hum  \
# 0          1  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 1          2  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 2          3  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 3          4  2011-01-01     1.0   False      6.0  0.199935  0.562475
# 4          5  2011-01-01     1.0   False      6.0  0.199935  0.562475
# ..       ...         ...     ...     ...      ...       ...       ...
# 385      615  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 386      616  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 387      617  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 388      618  2011-01-01     1.0   False      5.0  0.199935  0.562475
# 389      619  2011-01-01     1.0   False      6.0  0.199935  0.562475
#
#      windspeed  casual  registered        date  year  month       hour  \
# ...

# %%
#Validate Data
missing_values = new_dataset.isnull().sum()
# Print the number of missing values
print(missing_values)
# Out:
# instant       0
# dteday        0
# season        0
# holiday       0
# weekday       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# date          0
# year          0
# month         0
# hour          0
# weather       0
# temprature    0
# humidity      0
# count         0
# dtype: int64

# %%
#Drop column which is not required
new_dataset1=new_dataset.drop(['dteday','date','holiday'],axis=1)

new_dataset1
# Out:
#      instant  season  weekday     atemp       hum  windspeed  casual  \
# 0          1     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 1          2     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 2          3     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 3          4     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 4          5     1.0      6.0  0.199935  0.562475   0.194931   4.921
# ..       ...     ...      ...       ...       ...        ...     ...
# 385      615     1.0      5.0  0.199935  0.562475   0.194000   1.000
# 386      616     1.0      5.0  0.199935  0.562475   0.134300   1.000
# 387      617     1.0      5.0  0.199935  0.562475   0.358200   0.000
# 388      618     1.0      5.0  0.199935  0.562475   0.223900   1.000
# 389      619     1.0      6.0  0.199935  0.562475   0.358200   2.000
#
#      registered  year  month       hour   weather  temprature  humidity  \
# ...

# %%
def calculate_skewness(new_dataset1):
    """
    Calculate skewness of a dataset
    Args:
        data: List or Numpy array or Pandas Series of numerical data
    Returns:
        Float representing skewness
    """
    return skew(new_dataset1)

# %%
data_skewness = calculate_skewness(new_dataset1)
print(f"The skewness of the dataset is: {data_skewness}")
# Out:
# The skewness of the dataset is: [ 0.34766705         nan  0.02777796  0.9085976   0.98784648  0.54944621
#   4.32551292  1.64288835         nan -3.04769774 -0.10137363  2.09933611
#   0.89164183  0.32683939  1.99794662]
# C:\Users\girish.patil\AppData\Local\Temp\ipykernel_7792\1401397025.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return skew(new_dataset1)

# %%
#Skewness of dataset
import scipy.stats as stats

new_dataset1['skewness'] = stats.skew(new_dataset1['temprature'])
print(new_dataset1[['temprature']])
# Out:
#      temprature
# 0      0.230424
# 1      0.230424
# 2      0.230424
# 3      0.230424
# 4      0.230424
# ..          ...
# 385    0.227300
# 386    0.227300
# 387    0.212100
# 388    0.227300
# 389    0.197000
#
# [1610 rows x 1 columns]

# %%
#Skewness 
import scipy.stats as stats

new_dataset1['skewness'] = stats.skew(new_dataset1['temprature'])
print(new_dataset1[['temprature', 'skewness']])
# Out:
#      temprature  skewness
# 0      0.230424  0.891642
# 1      0.230424  0.891642
# 2      0.230424  0.891642
# 3      0.230424  0.891642
# 4      0.230424  0.891642
# ..          ...       ...
# 385    0.227300  0.891642
# 386    0.227300  0.891642
# 387    0.212100  0.891642
# 388    0.227300  0.891642
# 389    0.197000  0.891642
#
# [1610 rows x 2 columns]

# %%
new_data=new_dataset1
new_data['weather']= new_dataset1['weather'].astype(int)

# %%
new_data
# Out:
#      instant  season  weekday     atemp       hum  windspeed  casual  \
# 0          1     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 1          2     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 2          3     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 3          4     1.0      6.0  0.199935  0.562475   0.194931   4.921
# 4          5     1.0      6.0  0.199935  0.562475   0.194931   4.921
# ..       ...     ...      ...       ...       ...        ...     ...
# 385      615     1.0      5.0  0.199935  0.562475   0.194000   1.000
# 386      616     1.0      5.0  0.199935  0.562475   0.134300   1.000
# 387      617     1.0      5.0  0.199935  0.562475   0.358200   0.000
# 388      618     1.0      5.0  0.199935  0.562475   0.223900   1.000
# 389      619     1.0      6.0  0.199935  0.562475   0.358200   2.000
#
#      registered  year  month       hour  weather  temprature  humidity  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(new_data['humidity']).set_title('Histogram for Humidity')
plt.show()

# %%
#Heatmap

#Heatmap
import seaborn as sns

# Create a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(new_dataset1.corr(), annot=True, )
plt.show()
